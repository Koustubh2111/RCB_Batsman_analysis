# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import folium #Matches visualization
import yaml #reading data
from datetime import datetime
import glob

# %% [markdown]
# ###  AB de Villiers batting Analysis
# #### Data obtained from :  https://cricsheet.org/downloads/royal_challengers_bangalore.zip
# #### Ball to Ball data of every game played by RCB
# #### 5k series onwards - IPL 2011, pick data from there

# %% [markdown]
# ##### STEP 1: Data cleaning

# %%
All_ABD_Balls = []


our_team = 'Royal Challengers Bangalore'
root_dir = os.getcwd() + '\\royal_challengers_bangalore'
for file in glob.iglob(root_dir +'//*.yaml',recursive = True):
    

    with open(file, 'r') as stream:
        try:
            match_dict = yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            print(exc)

    
    ################## TRAVERSING THE RIGHT KEY BASED ON TOSS###########################
    if match_dict['info']['toss']['winner'] == our_team: #RCB won the toss
        if match_dict['info']['toss']['decision'] == 'field':
            
            #RCB won the toss and fielded - RCB bat second
            innings_deliveries = match_dict['innings'][1]['2nd innings']['deliveries']
            
        else:
            #RCB won the toss and batted - RCB bat first
            innings_deliveries = match_dict['innings'][0]['1st innings']['deliveries']

    else:
        #RCB has lost the toss
        if match_dict['info']['toss']['decision'] == 'field':
            
            #RCB lost the toss and opponent decided to field - RCB bat first
            innings_deliveries = match_dict['innings'][0]['1st innings']['deliveries']
        else:
            #RCB has lost the toss and opponent decided to bat - RCB bat second
            innings_deliveries = match_dict['innings'][1]['2nd innings']['deliveries']
            
    ########################## GETTING VENUE OF MATCH###################################
    try:
        
        match_city = match_dict['info']['city']
    except:
        match_city = match_dict['info']['venue']
        
    
        
    teams = match_dict['info']['teams']
    
    
    ########################### MATCH DATE ############################################
    if type(match_dict['info']['dates'][0]) == str: 
        year = match_dict['info']['dates'][0] #[0:4]
    else:
        year = match_dict['info']['dates'][0].strftime("%d-%b-%Y") #[-4:]
        
    ########################## GETTING OPPOSITION NAME #################################
    opposition = [team for team in teams if team != our_team][0]
    
    ########################## RUNNING THROUGH EACH BALL ###############################

    #Pick the name of the batsman, delivery
    #Iterating though every delivery - every ball a dict
    for ball in innings_deliveries:

        for item in ball.items():
            ######### ISOLATING ABD ##################
            if item[1]['batsman'] == 'AB de Villiers':
                #print(item)
                over = item[0]
                #batsman = item[1]['batsman']
                bowler = item[1]['bowler']
                non_striker = item[1]['non_striker']
                runs_scored_by_batsman = item[1]['runs']['batsman']
                extras = item[1]['runs']['extras']
                if extras > 0:
                    extra_type = list(item[1]['extras'].keys())[0]
                else:
                    extra_type = 'legal'

                All_ABD_Balls.append([over, \
                                      bowler, \
                                      non_striker, \
                                      runs_scored_by_batsman, \
                                      extras,\
                                      extra_type, \
                                      opposition, \
                                      match_city, \
                                      year])

# %%
match_dict
# Out:
# {'meta': {'data_version': 0.9,
#   'created': datetime.date(2016, 5, 30),
#   'revision': 1},
#  'info': {'city': 'Bangalore',
#   'competition': 'IPL',
#   'dates': [datetime.date(2016, 5, 29)],
#   'gender': 'male',
#   'match_type': 'T20',
#   'outcome': {'by': {'runs': 8}, 'winner': 'Sunrisers Hyderabad'},
#   'overs': 20,
#   'player_of_match': ['BCJ Cutting'],
#   'teams': ['Royal Challengers Bangalore', 'Sunrisers Hyderabad'],
#   'toss': {'decision': 'bat', 'winner': 'Sunrisers Hyderabad'},
#   'umpires': ['HDPK Dharmasena', 'BNJ Oxenford'],
#   'venue': 'M Chinnaswamy Stadium'},
#  'innings': [{'1st innings': {'team': 'Sunrisers Hyderabad',
#     'deliveries': [{0.1: {'batsman': 'DA Warner',
#        'bowler': 'S Aravind',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {0.2: {'batsman': 'S Dhawan',
#        'bowler': 'S Aravind',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {0.3: {'batsman': 'DA Warner',
#        'bowler': 'S Aravind',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {0.4: {'batsman': 'DA Warner',
#        'bowler': 'S Aravind',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {0.5: {'batsman': 'S Dhawan',
#        'bowler': 'S Aravind',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {0.6: {'batsman': 'S Dhawan',
#        'bowler': 'S Aravind',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {1.1: {'batsman': 'DA Warner',
#        'bowler': 'CH Gayle',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {1.2: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {1.3: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {1.4: {'batsman': 'DA Warner',
#        'bowler': 'CH Gayle',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {1.5: {'batsman': 'DA Warner',
#        'bowler': 'CH Gayle',
#        'extras': {'wides': 2},
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 0, 'extras': 2, 'total': 2}}},
#      {1.6: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {1.7: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {2.1: {'batsman': 'S Dhawan',
#        'bowler': 'S Aravind',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {2.2: {'batsman': 'S Dhawan',
#        'bowler': 'S Aravind',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {2.3: {'batsman': 'S Dhawan',
#        'bowler': 'S Aravind',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {2.4: {'batsman': 'S Dhawan',
#        'bowler': 'S Aravind',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {2.5: {'batsman': 'DA Warner',
#        'bowler': 'S Aravind',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {2.6: {'batsman': 'DA Warner',
#        'bowler': 'S Aravind',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {3.1: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {3.2: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {3.3: {'batsman': 'DA Warner',
#        'bowler': 'CH Gayle',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {3.4: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {3.5: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {3.6: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {4.1: {'batsman': 'DA Warner',
#        'bowler': 'SR Watson',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {4.2: {'batsman': 'DA Warner',
#        'bowler': 'SR Watson',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {4.3: {'batsman': 'S Dhawan',
#        'bowler': 'SR Watson',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {4.4: {'batsman': 'S Dhawan',
#        'bowler': 'SR Watson',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {4.5: {'batsman': 'DA Warner',
#        'bowler': 'SR Watson',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {4.6: {'batsman': 'DA Warner',
#        'bowler': 'SR Watson',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {5.1: {'batsman': 'DA Warner',
#        'bowler': 'CH Gayle',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {5.2: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'extras': {'wides': 1},
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {5.3: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {5.4: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {5.5: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {5.6: {'batsman': 'S Dhawan',
#        'bowler': 'CH Gayle',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {5.7: {'batsman': 'DA Warner',
#        'bowler': 'CH Gayle',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {6.1: {'batsman': 'S Dhawan',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {6.2: {'batsman': 'DA Warner',
#        'bowler': 'YS Chahal',
#        'non_striker': 'S Dhawan',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {6.3: {'batsman': 'S Dhawan',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {6.4: {'batsman': 'S Dhawan',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'fielders': ['CJ Jordan'],
#         'kind': 'caught',
#         'player_out': 'S Dhawan'}}},
#      {6.5: {'batsman': 'DA Warner',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {6.6: {'batsman': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {7.1: {'batsman': 'MC Henriques',
#        'bowler': 'Iqbal Abdulla',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {7.2: {'batsman': 'DA Warner',
#        'bowler': 'Iqbal Abdulla',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {7.3: {'batsman': 'DA Warner',
#        'bowler': 'Iqbal Abdulla',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {7.4: {'batsman': 'DA Warner',
#        'bowler': 'Iqbal Abdulla',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {7.5: {'batsman': 'MC Henriques',
#        'bowler': 'Iqbal Abdulla',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {7.6: {'batsman': 'DA Warner',
#        'bowler': 'Iqbal Abdulla',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {8.1: {'batsman': 'DA Warner',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {8.2: {'batsman': 'MC Henriques',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {8.3: {'batsman': 'DA Warner',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {8.4: {'batsman': 'DA Warner',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {8.5: {'batsman': 'DA Warner',
#        'bowler': 'YS Chahal',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {8.6: {'batsman': 'DA Warner',
#        'bowler': 'YS Chahal',
#        'extras': {'byes': 1},
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {9.1: {'batsman': 'DA Warner',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {9.2: {'batsman': 'DA Warner',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {9.3: {'batsman': 'DA Warner',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {9.4: {'batsman': 'DA Warner',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'MC Henriques',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {9.5: {'batsman': 'MC Henriques',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'fielders': ['YS Chahal'],
#         'kind': 'caught',
#         'player_out': 'MC Henriques'}}},
#      {9.6: {'batsman': 'DA Warner',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {10.1: {'batsman': 'Yuvraj Singh',
#        'bowler': 'SR Watson',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {10.2: {'batsman': 'Yuvraj Singh',
#        'bowler': 'SR Watson',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {10.3: {'batsman': 'DA Warner',
#        'bowler': 'SR Watson',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {10.4: {'batsman': 'Yuvraj Singh',
#        'bowler': 'SR Watson',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {10.5: {'batsman': 'Yuvraj Singh',
#        'bowler': 'SR Watson',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {10.6: {'batsman': 'Yuvraj Singh',
#        'bowler': 'SR Watson',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {11.1: {'batsman': 'DA Warner',
#        'bowler': 'CJ Jordan',
#        'extras': {'legbyes': 1},
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {11.2: {'batsman': 'Yuvraj Singh',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {11.3: {'batsman': 'Yuvraj Singh',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {11.4: {'batsman': 'Yuvraj Singh',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {11.5: {'batsman': 'DA Warner',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {11.6: {'batsman': 'DA Warner',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {12.1: {'batsman': 'DA Warner',
#        'bowler': 'YS Chahal',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {12.2: {'batsman': 'Yuvraj Singh',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {12.3: {'batsman': 'Yuvraj Singh',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {12.4: {'batsman': 'Yuvraj Singh',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {12.5: {'batsman': 'DA Warner',
#        'bowler': 'YS Chahal',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {12.6: {'batsman': 'Yuvraj Singh',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {13.1: {'batsman': 'Yuvraj Singh',
#        'bowler': 'S Aravind',
#        'non_striker': 'DA Warner',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {13.2: {'batsman': 'DA Warner',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {13.3: {'batsman': 'DA Warner',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'fielders': ['Iqbal Abdulla'],
#         'kind': 'caught',
#         'player_out': 'DA Warner'}}},
#      {13.4: {'batsman': 'DJ Hooda',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {13.5: {'batsman': 'Yuvraj Singh',
#        'bowler': 'S Aravind',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {13.6: {'batsman': 'DJ Hooda',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {14.1: {'batsman': 'Yuvraj Singh',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {14.2: {'batsman': 'DJ Hooda',
#        'bowler': 'YS Chahal',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {14.3: {'batsman': 'Yuvraj Singh',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {14.4: {'batsman': 'Yuvraj Singh',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {14.5: {'batsman': 'Yuvraj Singh',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {14.6: {'batsman': 'Yuvraj Singh',
#        'bowler': 'YS Chahal',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {15.1: {'batsman': 'Yuvraj Singh',
#        'bowler': 'S Aravind',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {15.2: {'batsman': 'Yuvraj Singh',
#        'bowler': 'S Aravind',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {15.3: {'batsman': 'DJ Hooda',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {15.4: {'batsman': 'DJ Hooda',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {15.5: {'batsman': 'Yuvraj Singh',
#        'bowler': 'S Aravind',
#        'non_striker': 'DJ Hooda',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {15.6: {'batsman': 'DJ Hooda',
#        'bowler': 'S Aravind',
#        'non_striker': 'Yuvraj Singh',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'fielders': ['V Kohli'],
#         'kind': 'caught',
#         'player_out': 'DJ Hooda'}}},
#      {16.1: {'batsman': 'Yuvraj Singh',
#        'bowler': 'CJ Jordan',
#        'extras': {'wides': 1},
#        'non_striker': 'BCJ Cutting',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {16.2: {'batsman': 'Yuvraj Singh',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'BCJ Cutting',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'fielders': ['SR Watson'],
#         'kind': 'caught',
#         'player_out': 'Yuvraj Singh'}}},
#      {16.3: {'batsman': 'NV Ojha',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'BCJ Cutting',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {16.4: {'batsman': 'NV Ojha',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'BCJ Cutting',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {16.5: {'batsman': 'BCJ Cutting',
#        'bowler': 'CJ Jordan',
#        'extras': {'legbyes': 1},
#        'non_striker': 'NV Ojha',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {16.6: {'batsman': 'NV Ojha',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'BCJ Cutting',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {16.7: {'batsman': 'NV Ojha',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'BCJ Cutting',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {17.1: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'extras': {'wides': 1},
#        'non_striker': 'NV Ojha',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {17.2: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'extras': {'wides': 1},
#        'non_striker': 'NV Ojha',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {17.3: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'NV Ojha',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'fielders': ['SR Watson'],
#         'kind': 'run out',
#         'player_out': 'NV Ojha'}}},
#      {17.4: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'Bipul Sharma',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {17.5: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'Bipul Sharma',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {17.6: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'Bipul Sharma',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {17.7: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'Bipul Sharma',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {17.8: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'Bipul Sharma',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {18.1: {'batsman': 'Bipul Sharma',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'BCJ Cutting',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {18.2: {'batsman': 'BCJ Cutting',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'Bipul Sharma',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {18.3: {'batsman': 'Bipul Sharma',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'BCJ Cutting',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {18.4: {'batsman': 'Bipul Sharma',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'BCJ Cutting',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'fielders': ['YS Chahal'],
#         'kind': 'caught',
#         'player_out': 'Bipul Sharma'}}},
#      {18.5: {'batsman': 'BCJ Cutting',
#        'bowler': 'CJ Jordan',
#        'extras': {'wides': 5},
#        'non_striker': 'B Kumar',
#        'runs': {'batsman': 0, 'extras': 5, 'total': 5}}},
#      {18.6: {'batsman': 'BCJ Cutting',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'B Kumar',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {18.7: {'batsman': 'BCJ Cutting',
#        'bowler': 'CJ Jordan',
#        'non_striker': 'B Kumar',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {19.1: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'B Kumar',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {19.2: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'B Kumar',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {19.3: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'B Kumar',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {19.4: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'B Kumar',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {19.5: {'batsman': 'B Kumar',
#        'bowler': 'SR Watson',
#        'non_striker': 'BCJ Cutting',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {19.6: {'batsman': 'BCJ Cutting',
#        'bowler': 'SR Watson',
#        'non_striker': 'B Kumar',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}]}},
#   {'2nd innings': {'team': 'Royal Challengers Bangalore',
#     'deliveries': [{0.1: {'batsman': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {0.2: {'batsman': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'extras': {'legbyes': 1},
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {0.3: {'batsman': 'V Kohli',
#        'bowler': 'B Kumar',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {0.4: {'batsman': 'V Kohli',
#        'bowler': 'B Kumar',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {0.5: {'batsman': 'V Kohli',
#        'bowler': 'B Kumar',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {0.6: {'batsman': 'V Kohli',
#        'bowler': 'B Kumar',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {1.1: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'extras': {'wides': 1},
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {1.2: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {1.3: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {1.4: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {1.5: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'extras': {'wides': 1},
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {1.6: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {1.7: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {1.8: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {2.1: {'batsman': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {2.2: {'batsman': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'extras': {'legbyes': 1},
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {2.3: {'batsman': 'V Kohli',
#        'bowler': 'B Kumar',
#        'extras': {'wides': 1},
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {2.4: {'batsman': 'V Kohli',
#        'bowler': 'B Kumar',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {2.5: {'batsman': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {2.6: {'batsman': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {2.7: {'batsman': 'CH Gayle',
#        'bowler': 'B Kumar',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {3.1: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {3.2: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {3.3: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {3.4: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {3.5: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {3.6: {'batsman': 'CH Gayle',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {4.1: {'batsman': 'V Kohli',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {4.2: {'batsman': 'V Kohli',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {4.3: {'batsman': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {4.4: {'batsman': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {4.5: {'batsman': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {4.6: {'batsman': 'V Kohli',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {5.1: {'batsman': 'V Kohli',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {5.2: {'batsman': 'V Kohli',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {5.3: {'batsman': 'V Kohli',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {5.4: {'batsman': 'CH Gayle',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {5.5: {'batsman': 'CH Gayle',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {5.6: {'batsman': 'V Kohli',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {6.1: {'batsman': 'CH Gayle',
#        'bowler': 'MC Henriques',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {6.2: {'batsman': 'CH Gayle',
#        'bowler': 'MC Henriques',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {6.3: {'batsman': 'CH Gayle',
#        'bowler': 'MC Henriques',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {6.4: {'batsman': 'V Kohli',
#        'bowler': 'MC Henriques',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {6.5: {'batsman': 'V Kohli',
#        'bowler': 'MC Henriques',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {6.6: {'batsman': 'V Kohli',
#        'bowler': 'MC Henriques',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {7.1: {'batsman': 'V Kohli',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {7.2: {'batsman': 'V Kohli',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {7.3: {'batsman': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'extras': {'wides': 1},
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {7.4: {'batsman': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {7.5: {'batsman': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {7.6: {'batsman': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {7.7: {'batsman': 'V Kohli',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {8.1: {'batsman': 'V Kohli',
#        'bowler': 'MC Henriques',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {8.2: {'batsman': 'V Kohli',
#        'bowler': 'MC Henriques',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {8.3: {'batsman': 'CH Gayle',
#        'bowler': 'MC Henriques',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {8.4: {'batsman': 'CH Gayle',
#        'bowler': 'MC Henriques',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {8.5: {'batsman': 'CH Gayle',
#        'bowler': 'MC Henriques',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {8.6: {'batsman': 'CH Gayle',
#        'bowler': 'MC Henriques',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {9.1: {'batsman': 'V Kohli',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {9.2: {'batsman': 'V Kohli',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {9.3: {'batsman': 'V Kohli',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {9.4: {'batsman': 'CH Gayle',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {9.5: {'batsman': 'CH Gayle',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {9.6: {'batsman': 'V Kohli',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {10.1: {'batsman': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {10.2: {'batsman': 'V Kohli',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'CH Gayle',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {10.3: {'batsman': 'CH Gayle',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'fielders': ['Bipul Sharma'],
#         'kind': 'caught',
#         'player_out': 'CH Gayle'}}},
#      {10.4: {'batsman': 'V Kohli',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {10.5: {'batsman': 'V Kohli',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {10.6: {'batsman': 'V Kohli',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {11.1: {'batsman': 'AB de Villiers',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {11.2: {'batsman': 'V Kohli',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {11.3: {'batsman': 'V Kohli',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {11.4: {'batsman': 'AB de Villiers',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {11.5: {'batsman': 'V Kohli',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {11.6: {'batsman': 'AB de Villiers',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {12.1: {'batsman': 'AB de Villiers',
#        'bowler': 'BB Sran',
#        'non_striker': 'V Kohli',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {12.2: {'batsman': 'V Kohli',
#        'bowler': 'BB Sran',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {12.3: {'batsman': 'V Kohli',
#        'bowler': 'BB Sran',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {12.4: {'batsman': 'V Kohli',
#        'bowler': 'BB Sran',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {12.5: {'batsman': 'V Kohli',
#        'bowler': 'BB Sran',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'kind': 'bowled', 'player_out': 'V Kohli'}}},
#      {12.6: {'batsman': 'KL Rahul',
#        'bowler': 'BB Sran',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {13.1: {'batsman': 'KL Rahul',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {13.2: {'batsman': 'KL Rahul',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {13.3: {'batsman': 'AB de Villiers',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'KL Rahul',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {13.4: {'batsman': 'KL Rahul',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'AB de Villiers',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {13.5: {'batsman': 'AB de Villiers',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'KL Rahul',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'fielders': ['MC Henriques'],
#         'kind': 'caught',
#         'player_out': 'AB de Villiers'}}},
#      {13.6: {'batsman': 'KL Rahul',
#        'bowler': 'Bipul Sharma',
#        'non_striker': 'SR Watson',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {14.1: {'batsman': 'KL Rahul',
#        'bowler': 'MC Henriques',
#        'non_striker': 'SR Watson',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {14.2: {'batsman': 'SR Watson',
#        'bowler': 'MC Henriques',
#        'non_striker': 'KL Rahul',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {14.3: {'batsman': 'KL Rahul',
#        'bowler': 'MC Henriques',
#        'non_striker': 'SR Watson',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {14.4: {'batsman': 'SR Watson',
#        'bowler': 'MC Henriques',
#        'non_striker': 'KL Rahul',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {14.5: {'batsman': 'SR Watson',
#        'bowler': 'MC Henriques',
#        'non_striker': 'KL Rahul',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {14.6: {'batsman': 'SR Watson',
#        'bowler': 'MC Henriques',
#        'non_striker': 'KL Rahul',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {15.1: {'batsman': 'KL Rahul',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'SR Watson',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {15.2: {'batsman': 'SR Watson',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'KL Rahul',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {15.3: {'batsman': 'KL Rahul',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'SR Watson',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'kind': 'bowled', 'player_out': 'KL Rahul'}}},
#      {15.4: {'batsman': 'Sachin Baby',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'SR Watson',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {15.5: {'batsman': 'Sachin Baby',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'SR Watson',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {15.6: {'batsman': 'SR Watson',
#        'bowler': 'BCJ Cutting',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {16.1: {'batsman': 'SR Watson',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {16.2: {'batsman': 'SR Watson',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {16.3: {'batsman': 'SR Watson',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'fielders': ['MC Henriques'],
#         'kind': 'caught',
#         'player_out': 'SR Watson'}}},
#      {16.4: {'batsman': 'Sachin Baby',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'STR Binny',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {16.5: {'batsman': 'STR Binny',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {16.6: {'batsman': 'STR Binny',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {17.1: {'batsman': 'STR Binny',
#        'bowler': 'B Kumar',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {17.2: {'batsman': 'STR Binny',
#        'bowler': 'B Kumar',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {17.3: {'batsman': 'Sachin Baby',
#        'bowler': 'B Kumar',
#        'non_striker': 'STR Binny',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {17.4: {'batsman': 'STR Binny',
#        'bowler': 'B Kumar',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {17.5: {'batsman': 'STR Binny',
#        'bowler': 'B Kumar',
#        'extras': {'legbyes': 1},
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {17.6: {'batsman': 'Sachin Baby',
#        'bowler': 'B Kumar',
#        'non_striker': 'STR Binny',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#      {18.1: {'batsman': 'STR Binny',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1},
#        'wicket': {'fielders': ['DJ Hooda', 'NV Ojha'],
#         'kind': 'run out',
#         'player_out': 'STR Binny'}}},
#      {18.2: {'batsman': 'CJ Jordan',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {18.3: {'batsman': 'CJ Jordan',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {18.4: {'batsman': 'CJ Jordan',
#        'bowler': 'Mustafizur Rahman',
#        'extras': {'legbyes': 1},
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {18.5: {'batsman': 'Sachin Baby',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'CJ Jordan',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {18.6: {'batsman': 'Sachin Baby',
#        'bowler': 'Mustafizur Rahman',
#        'non_striker': 'CJ Jordan',
#        'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#      {19.1: {'batsman': 'CJ Jordan',
#        'bowler': 'B Kumar',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {19.2: {'batsman': 'Sachin Baby',
#        'bowler': 'B Kumar',
#        'non_striker': 'CJ Jordan',
#        'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#      {19.3: {'batsman': 'Sachin Baby',
#        'bowler': 'B Kumar',
#        'non_striker': 'CJ Jordan',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#        'wicket': {'fielders': ['NV Ojha'],
#         'kind': 'run out',
#         'player_out': 'CJ Jordan'}}},
#      {19.4: {'batsman': 'Iqbal Abdulla',
#        'bowler': 'B Kumar',
#        'extras': {'legbyes': 1},
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {19.5: {'batsman': 'Sachin Baby',
#        'bowler': 'B Kumar',
#        'non_striker': 'Iqbal Abdulla',
#        'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#      {19.6: {'batsman': 'Iqbal Abdulla',
#        'bowler': 'B Kumar',
#        'non_striker': 'Sachin Baby',
#        'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}]}}]}

# %%
#Create dataframe using abd all balls
columns = ['Over', \
           'Bowler', \
           'Non_Striker',\
           'Runs', \
           'Extras', \
           'Extra Type', \
           'Opposition', \
           'Venue', \
           'Year']
df = pd.DataFrame(data = All_ABD_Balls, \
                  columns = columns)
df.head()
# Out:
#    Over          Bowler   Non_Striker  Runs  Extras Extra Type  \
# 0   1.5  Sandeep Sharma  Vishnu Vinod     4       0      legal
# 1   1.6  Sandeep Sharma  Vishnu Vinod     0       0      legal
# 2   2.4       MM Sharma  Vishnu Vinod     0       0      legal
# 3   2.5       MM Sharma  Vishnu Vinod     0       0      legal
# 4   2.6       MM Sharma  Vishnu Vinod     6       0      legal
#
#         Opposition   Venue         Year
# 0  Kings XI Punjab  Indore  10-Apr-2017
# 1  Kings XI Punjab  Indore  10-Apr-2017
# 2  Kings XI Punjab  Indore  10-Apr-2017
# 3  Kings XI Punjab  Indore  10-Apr-2017
# 4  Kings XI Punjab  Indore  10-Apr-2017

# %%
#Changing team names
old_names = ['Deccan Chargers', 'Kings XI Punjab', 'Rising Pune Supergiant', 'Delhi Daredevils']
new_names = ['Sunrisers Hyderabad', 'Punjab Kings', 'Rising Pune Supergiants', 'Delhi Capitals']
for old, new in zip(old_names, new_names):
    df.loc[df['Opposition'] == old, 'Opposition'] = new

# %%
df.info()

# %% [markdown]
# ##### Some Exploratory Analysis
# ##### Q1. How many runs has AB scored in each year of the IPL over the full innings

# %%
fig, ax = plt.subplots(figsize = (40,10))
sns.countplot(x = sorted(df['Year']), ax = ax)
ax.tick_params(axis = 'x', labelrotation = 90, labelsize = 20)
#JOB: sort the date strings, plot does not make sense

# %% [markdown]
# ##### Q2. Runs scored by AB from 2011 - 2021 against each team

# %%
by_opp = df.groupby('Opposition').sum()

fig, ax = plt.subplots(figsize = (10,5))
sns.barplot(x = "Runs", y = "Opposition", data = df, estimator = sum, ci = None)
ax.tick_params(axis = 'y', labelsize = 12)
ax.tick_params(axis = 'x', labelsize = 12)
ax.set_xlabel('Runs', fontsize = 12);
ax.set_ylabel('Opposition', fontsize = 12);
#JOB Merge teams like SRH DC, RPS, DC and DD

# %% [markdown]
# ##### Q3. Boundary count per team;  sixes and four

# %%
filter_df = df[['Opposition', 'Runs']]
run_count = []
for opp in filter_df['Opposition'].unique():
    all_run_count = filter_df[filter_df['Opposition'] == opp].groupby('Runs').count()   
    #Count run counts
    #0,1,2,3,4,6
    run_count.append([all_run_count.iloc[i][0] for i in range(len(all_run_count))])
#JOB: CHECK IF THERE IS A BETTER WAY

fig, ax = plt.subplots(figsize = (15,5), nrows = 1, ncols = 2)
four_count = [opp[-2] for opp in run_count]
sns.barplot(y = df['Opposition'].unique(), x = six_count, ax = ax[0])
ax[0].tick_params(axis = 'x', labelsize = 12)
ax[0].tick_params(axis = 'y', labelsize = 12)
ax[0].set_title('Number of Fours by AB de Villiers', fontsize = 12)
ax[0].set_xlim([0, 60])

six_count = [opp[-1] for opp in run_count]
sns.barplot(y = df['Opposition'].unique(), x = six_count, ax = ax[1])
ax[1].tick_params(axis = 'x', labelsize = 12)
ax[1].set_title('Number of Sixes by AB de Villiers', fontsize = 12)
ax[1].set_yticks([])
ax[1].set_xlim([0, 60])
#JOB: The counts for RPS and PW are wrong, not all of them have boundaries

# %% [markdown]
# ####                                                       More Exploraratory questions to ask
# ##### Q4.  Number of dots, ones twos and threes per team
# ##### Q5. percentage of runs per type of bowler - need manual labelling of bowler or data scraping
# ##### Q6. Death overs 16 - 20; percentage of runs and consistency
# ##### Q7. Percentage of dismissala per bowler
# ##### Q8. What is AB's strength and weakness per venue - bowler type, if you get line and length then include
# ##### Q9. How would you quantify bowler's performance
#
# ####                                                                   Visualization Questions
# ##### 1. In the map of india/UAE, where does AB have the most runs
# ##### 2. Is there significant difference between AB's strike rate when an incompetent non striker is at the other end

# %%
#exploratory solutions

# %% [markdown]
# ## Question
# ### What influences AB's run (Boundaries or not boundaries)
# 1. Dot ball - excellent line and length, bowling to the field inside the thirty yard circle, excelent fielding in gaps, batting with taillenders
# 2. Ones, twos - hit into the gaps but not timed well (including edges), batting with taileenders and end of over (single)
# 3. fours, sixes - bowler slot ball, short boundary, timed gaps, death overs needing runs
#
# #### Can we predict the type of run (dots, non boundaries, boundaries) from
# ##### 1. Bowler type
# ##### 2. bowler dot percent (0 - 1) - higher dot percent indicative of good line and length or bowling to inner field or good fielding or batting with tailenders
# ##### 3.

# %% [markdown]
# ### FEATURE ANALYSIS
# ### https://machinelearningmastery.com/feature-selection-with-real-and-categorical-data/
# ### "Statistical-based feature selection methods involve evaluating the relationship between each input variable and the target variable using statistics and selecting those input variables that have the strongest relationship with the target variable"
#
# ### "The statistical measures used in filter-based feature selection are generally calculated one input variable at a time with the target variable"
#
# ### For a regression modelling probem - a correlation like pearson for linear and spearman rank for non linear is used
#
# ### For Classification problem  ANOVA correlation cefficient for linear or kendall's rank coefficient for non linear is used
#
# ###
#
# ## JOBS TODAY:
# ### Scrape non striker data

# %%
import json
with open('bowler_stats.json') as f:
    bowler_stat = json.load(f)

# %%
df['Non_Striker'].unique()
# Out:
# array(['Vishnu Vinod', 'KM Jadhav', 'Mandeep Singh', 'STR Binny',
#        'V Kohli', 'CH Gayle', 'TM Head', 'Q de Kock', 'CJ Anderson',
#        'PA Patel', 'MM Ali', 'SN Khan', 'C de Grandhomme', 'SO Hetmyer',
#        'S Dube', 'MP Stoinis', 'AD Nath', 'D Padikkal', 'JR Philippe',
#        'Washington Sundar', 'AJ Finch', 'Gurkeerat Singh', 'NA Saini',
#        'GJ Maxwell', 'Shahbaz Ahmed', 'DT Christian', 'KA Jamieson',
#        'HV Patel', 'RM Patidar', 'DR Sams', 'MA Agarwal', 'SS Tiwary',
#        'AUK Pathan', 'TM Dilshan', 'CA Pujara', 'JJ van der Wath',
#        'M Kaif', 'A Mithun', 'KB Arun Karthik', 'LA Pomersbach',
#        'DL Vettori', 'R Vinay Kumar', 'AB McDonald', 'J Syed Mohammad',
#        'R Rampaul', 'MC Henriques', 'Yuvraj Singh', 'JA Morkel',
#        'RR Rossouw', 'MA Starc', 'S Rana', 'VH Zol', 'DJG Sammy',
#        'SA Abbott', 'KD Karthik', 'D Wiese', 'SR Watson', 'KL Rahul',
#        'Sachin Baby', 'Iqbal Abdulla'], dtype=object)

# %%
df.to_csv('ABD_ballToball.csv')
