# %%
import pandas as pd
import json
import numpy as np
from datetime import datetime
from collections import ChainMap
import os

# %% [markdown]
# ### CLEAN UP OF MAIN ABD DATAFRAME

# %%
#Load ABD main data
ABD_main = pd.read_csv('ABD_ballToball.csv')

# %%
#Dropping unnecessary column
ABD_main.drop(columns = 'Unnamed: 0', inplace = True)

# %%
#Appropriate Col name
ABD_main.rename(columns = {'Year' : 'Date', 'Non_Striker' : 'Non Striker'}, inplace = True)

# %%
#Convert date string to timestamp
ABD_main['Date'] = ABD_main['Date'].apply(pd.to_datetime)

# %%
ABD_main.head()
# Out:
#    Over          Bowler   Non Striker  Runs  Extras ExtraType   Status  \
# 0   1.5  Sandeep Sharma  Vishnu Vinod     4       0     legal  Not Out
# 1   1.6  Sandeep Sharma  Vishnu Vinod     0       0     legal  Not Out
# 2   2.4       MM Sharma  Vishnu Vinod     0       0     legal  Not Out
# 3   2.5       MM Sharma  Vishnu Vinod     0       0     legal  Not Out
# 4   2.6       MM Sharma  Vishnu Vinod     6       0     legal  Not Out
#
#    BattingOrder  WicketsInHand       Opposition   Venue       Date
# 0             3              7  Kings XI Punjab  Indore 2017-04-10
# 1             3              7  Kings XI Punjab  Indore 2017-04-10
# 2             3              7  Kings XI Punjab  Indore 2017-04-10
# 3             3              7  Kings XI Punjab  Indore 2017-04-10
# 4             3              7  Kings XI Punjab  Indore 2017-04-10

# %%
#Changing team names
old_names = ['Deccan Chargers', 'Kings XI Punjab', 'Rising Pune Supergiant', 'Delhi Daredevils']
new_names = ['Sunrisers Hyderabad', 'Punjab Kings', 'Rising Pune Supergiants', 'Delhi Capitals']
for old, new in zip(old_names, new_names):
    ABD_main.loc[ABD_main['Opposition'] == old, 'Opposition'] = new

# %%
ABD_main['Opposition'].unique()
# Out:
# array(['Punjab Kings', 'Mumbai Indians', 'Rising Pune Supergiants',
#        'Kolkata Knight Riders', 'Gujarat Lions', 'Rajasthan Royals',
#        'Delhi Capitals', 'Chennai Super Kings', 'Sunrisers Hyderabad',
#        'Kochi Tuskers Kerala', 'Pune Warriors'], dtype=object)

# %%
import sys
sys.path.append(os.getcwd() + '\\DataAfterScraping\\')

# %%
#Load Bowler type
#This was due to having three files and the recapthca problem
#JOB: FIX recapthca
path = os.getcwd() + '\\DataAfterScraping\\'
with open(path + 'bowler_type_1.json') as f:
    bowler_type1 = json.load(f)
with open(path + 'bowler_type_2.json') as f:
    bowler_type2 = json.load(f)
with open(path + 'bowler_type_3.json') as f:
    bowler_type3 = json.load(f)
bowler_type = bowler_type1 + bowler_type2 + bowler_type3
#convert list of dicts into main dict
bowler_type_dict = dict(ChainMap(*bowler_type))

# %%
#Create a new column for bowler ype using map from bowler
#https://stackoverflow.com/questions/24216425/adding-a-new-pandas-column-with-mapped-value-from-a-dictionary
ABD_main['Bowler Type'] = ABD_main['Bowler'].map(bowler_type_dict)

# %%
#convert Overs numeric values into categorical
#https://stackoverflow.com/questions/49382207/how-to-map-numeric-data-into-categories-bins-in-pandas-dataframe

bins = [0, 6, 10, 16, 20]
names = ['Power Play', 'Middle Overs (6-10)', 'Middle Overs (10-16)', 'Death Overs']
ABD_main['Over category'] = pd.cut(ABD_main['Over'], bins, labels=names)

# %%
ABD_main.head()
# Out:
#    Over          Bowler   Non Striker  Runs  Extras ExtraType   Status  \
# 0   1.5  Sandeep Sharma  Vishnu Vinod     4       0     legal  Not Out
# 1   1.6  Sandeep Sharma  Vishnu Vinod     0       0     legal  Not Out
# 2   2.4       MM Sharma  Vishnu Vinod     0       0     legal  Not Out
# 3   2.5       MM Sharma  Vishnu Vinod     0       0     legal  Not Out
# 4   2.6       MM Sharma  Vishnu Vinod     6       0     legal  Not Out
#
#    BattingOrder  WicketsInHand    Opposition   Venue       Date  \
# 0             3              7  Punjab Kings  Indore 2017-04-10
# 1             3              7  Punjab Kings  Indore 2017-04-10
# 2             3              7  Punjab Kings  Indore 2017-04-10
# 3             3              7  Punjab Kings  Indore 2017-04-10
# 4             3              7  Punjab Kings  Indore 2017-04-10
#
#              Bowler Type Over category
# 0  Right-arm fast-medium    Power Play
# 1  Right-arm fast-medium    Power Play
# 2  Right-arm fast-medium    Power Play
# 3  Right-arm fast-medium    Power Play
# 4  Right-arm fast-medium    Power Play

# %%
new_cols = ['Date', 'Over', 'Over category', 'BattingOrder', 'WicketsInHand', 'Bowler', 'Bowler Type', 'Runs', 'Extras', 'ExtraType', 'Status',  \
            'Non Striker', 'Opposition', 'Venue']
ABD_main = ABD_main[new_cols]

# %%
#Manual entry of missing columns for bowler types
#Bowling types of Raiphi gomez, kamran khan, Shalb srivastava, AN ahmed
missing_types = ['Right-arm medium', 'Left-arm fast-medium', 'Left-arm fast-medium', 'Right-arm fast-medium']
for bowler_missing_type, missing_type in \
                    zip(ABD_main.loc[ABD_main['Bowler Type'] == ' ', 'Bowler'].unique(), missing_types):
    ABD_main['Bowler Type'][ABD_main['Bowler'] == bowler_missing_type] = missing_type
#JOB understand the warning
# Out:
# C:\Users\Owner\Anaconda3\envs\NeuralNets\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#ABD_main.drop(columns = 'Over', inplace = True)

# %%
ABD_main.head(50)
# Out:
#          Date  Over         Over category  BattingOrder  WicketsInHand  \
# 0  2017-04-10   1.5            Power Play             3              7
# 1  2017-04-10   1.6            Power Play             3              7
# 2  2017-04-10   2.4            Power Play             3              7
# 3  2017-04-10   2.5            Power Play             3              7
# 4  2017-04-10   2.6            Power Play             3              7
# 5  2017-04-10   3.4            Power Play             3              6
# 6  2017-04-10   4.1            Power Play             3              6
# 7  2017-04-10   4.2            Power Play             3              6
# 8  2017-04-10   4.3            Power Play             3              6
# 9  2017-04-10   4.5            Power Play             3              6
# 10 2017-04-10   5.1            Power Play             3              5
# 11 2017-04-10   6.1   Middle Overs (6-10)             3              5
# 12 2017-04-10   6.6   Middle Overs (6-10)             3              5
# 13 2017-04-10   8.4   Middle Overs (6-10)             3              5
# 14 2017-04-10   8.5   Middle Overs (6-10)             3              5
# 15 2017-04-10   9.1   Middle Overs (6-10)             3              5
# 16 2017-04-10   9.3   Middle Overs (6-10)             3              5
# 17 2017-04-10   9.4   Middle Overs (6-10)             3              5
# 18 2017-04-10   9.6   Middle Overs (6-10)             3              5
# 19 2017-04-10  10.3  Middle Overs (10-16)             3              5
# 20 2017-04-10  10.4  Middle Overs (10-16)             3              5
# 21 2017-04-10  10.6  Middle Overs (10-16)             3              5
# 22 2017-04-10  11.1  Middle Overs (10-16)             3              5
# 23 2017-04-10  11.3  Middle Overs (10-16)             3              5
# 24 2017-04-10  11.5  Middle Overs (10-16)             3              5
# 25 2017-04-10  12.3  Middle Overs (10-16)             3              5
# 26 2017-04-10  13.2  Middle Overs (10-16)             3              4
# 27 2017-04-10  13.3  Middle Overs (10-16)             3              4
# 28 2017-04-10  14.6  Middle Overs (10-16)             3              4
# 29 2017-04-10  15.3  Middle Overs (10-16)             3              4
# 30 2017-04-10  15.4  Middle Overs (10-16)             3              4
# 31 2017-04-10  16.2           Death Overs             3              4
# 32 2017-04-10  16.3           Death Overs             3              4
# 33 2017-04-10  16.4           Death Overs             3              4
# 34 2017-04-10  16.6           Death Overs             3              4
# 35 2017-04-10  16.7           Death Overs             3              4
# 36 2017-04-10  17.4           Death Overs             3              4
# 37 2017-04-10  17.5           Death Overs             3              4
# 38 2017-04-10  17.6           Death Overs             3              4
# 39 2017-04-10  18.2           Death Overs             3              4
# 40 2017-04-10  18.3           Death Overs             3              4
# 41 2017-04-10  18.4           Death Overs             3              4
# 42 2017-04-10  18.5           Death Overs             3              4
# 43 2017-04-10  18.6           Death Overs             3              4
# 44 2017-04-10  18.7           Death Overs             3              4
# 45 2017-04-10  19.1           Death Overs             3              4
# 46 2017-04-10  19.4           Death Overs             3              4
# 47 2017-04-10  19.5           Death Overs             3              4
# 48 2017-04-10  19.6           Death Overs             3              4
# 49 2017-04-14   9.3   Middle Overs (6-10)             3              7
#
#             Bowler            Bowler Type  Runs  Extras ExtraType   Status  \
# 0   Sandeep Sharma  Right-arm fast-medium     4       0     legal  Not Out
# 1   Sandeep Sharma  Right-arm fast-medium     0       0     legal  Not Out
# 2        MM Sharma  Right-arm fast-medium     0       0     legal  Not Out
# 3        MM Sharma  Right-arm fast-medium     0       0     legal  Not Out
# 4        MM Sharma  Right-arm fast-medium     6       0     legal  Not Out
# 5   Sandeep Sharma  Right-arm fast-medium     1       0     legal  Not Out
# 6         VR Aaron         Right-arm fast     0       0     legal  Not Out
# 7         VR Aaron         Right-arm fast     0       0     legal  Not Out
# 8         VR Aaron         Right-arm fast     1       0     legal  Not Out
# 9         VR Aaron         Right-arm fast     1       0     legal  Not Out
# 10  Sandeep Sharma  Right-arm fast-medium     1       0     legal  Not Out
# 11        VR Aaron         Right-arm fast     1       0     legal  Not Out
# 12        VR Aaron         Right-arm fast     4       0     legal  Not Out
# 13     T Natarajan   Left-arm fast-medium     0       1     wides  Not Out
# 14     T Natarajan   Left-arm fast-medium     1       0     legal  Not Out
# 15      MP Stoinis       Right-arm medium     1       0     legal  Not Out
# 16      MP Stoinis       Right-arm medium     2       0     legal  Not Out
# 17      MP Stoinis       Right-arm medium     1       0     legal  Not Out
# 18      MP Stoinis       Right-arm medium     0       0     legal  Not Out
# 19        AR Patel      Left-arm orthodox     0       0     legal  Not Out
# 20        AR Patel      Left-arm orthodox     1       0     legal  Not Out
# 21        AR Patel      Left-arm orthodox     1       0     legal  Not Out
# 22      MP Stoinis       Right-arm medium     1       0     legal  Not Out
# 23      MP Stoinis       Right-arm medium     1       0     legal  Not Out
# 24      MP Stoinis       Right-arm medium     1       0     legal  Not Out
# 25        AR Patel      Left-arm orthodox     1       0     legal  Not Out
# 26        VR Aaron         Right-arm fast     0       0     legal  Not Out
# 27        VR Aaron         Right-arm fast     1       0     legal  Not Out
# 28        AR Patel      Left-arm orthodox     0       0     legal  Not Out
# 29        VR Aaron         Right-arm fast     6       0     legal  Not Out
# 30        VR Aaron         Right-arm fast     1       0     legal  Not Out
# 31      MP Stoinis       Right-arm medium     0       0     legal  Not Out
# 32      MP Stoinis       Right-arm medium     6       0     legal  Not Out
# 33      MP Stoinis       Right-arm medium     1       0     legal  Not Out
# 34      MP Stoinis       Right-arm medium     0       1     wides  Not Out
# 35      MP Stoinis       Right-arm medium     6       0     legal  Not Out
# 36       MM Sharma  Right-arm fast-medium     2       0     legal  Not Out
# 37       MM Sharma  Right-arm fast-medium     6       0     legal  Not Out
# 38       MM Sharma  Right-arm fast-medium     0       0     legal  Not Out
# 39  Sandeep Sharma  Right-arm fast-medium     4       0     legal  Not Out
# 40  Sandeep Sharma  Right-arm fast-medium     6       0     legal  Not Out
# 41  Sandeep Sharma  Right-arm fast-medium     6       0     legal  Not Out
# 42  Sandeep Sharma  Right-arm fast-medium     0       1     wides  Not Out
# 43  Sandeep Sharma  Right-arm fast-medium     0       0     legal  Not Out
# 44  Sandeep Sharma  Right-arm fast-medium     1       0     legal  Not Out
# 45       MM Sharma  Right-arm fast-medium     1       0     legal  Not Out
# 46       MM Sharma  Right-arm fast-medium     0       0     legal  Not Out
# 47       MM Sharma  Right-arm fast-medium     6       0     legal  Not Out
# 48       MM Sharma  Right-arm fast-medium     6       0     legal  Not Out
# 49       HH Pandya  Right-arm fast-medium     1       0     legal  Not Out
#
#       Non Striker      Opposition      Venue
# 0    Vishnu Vinod    Punjab Kings     Indore
# 1    Vishnu Vinod    Punjab Kings     Indore
# 2    Vishnu Vinod    Punjab Kings     Indore
# 3    Vishnu Vinod    Punjab Kings     Indore
# 4    Vishnu Vinod    Punjab Kings     Indore
# 5       KM Jadhav    Punjab Kings     Indore
# 6       KM Jadhav    Punjab Kings     Indore
# 7       KM Jadhav    Punjab Kings     Indore
# 8       KM Jadhav    Punjab Kings     Indore
# 9       KM Jadhav    Punjab Kings     Indore
# 10  Mandeep Singh    Punjab Kings     Indore
# 11  Mandeep Singh    Punjab Kings     Indore
# 12  Mandeep Singh    Punjab Kings     Indore
# 13  Mandeep Singh    Punjab Kings     Indore
# 14  Mandeep Singh    Punjab Kings     Indore
# 15  Mandeep Singh    Punjab Kings     Indore
# 16  Mandeep Singh    Punjab Kings     Indore
# 17  Mandeep Singh    Punjab Kings     Indore
# 18  Mandeep Singh    Punjab Kings     Indore
# 19  Mandeep Singh    Punjab Kings     Indore
# 20  Mandeep Singh    Punjab Kings     Indore
# 21  Mandeep Singh    Punjab Kings     Indore
# 22  Mandeep Singh    Punjab Kings     Indore
# 23  Mandeep Singh    Punjab Kings     Indore
# 24  Mandeep Singh    Punjab Kings     Indore
# 25  Mandeep Singh    Punjab Kings     Indore
# 26      STR Binny    Punjab Kings     Indore
# 27      STR Binny    Punjab Kings     Indore
# 28      STR Binny    Punjab Kings     Indore
# 29      STR Binny    Punjab Kings     Indore
# 30      STR Binny    Punjab Kings     Indore
# 31      STR Binny    Punjab Kings     Indore
# 32      STR Binny    Punjab Kings     Indore
# 33      STR Binny    Punjab Kings     Indore
# 34      STR Binny    Punjab Kings     Indore
# 35      STR Binny    Punjab Kings     Indore
# 36      STR Binny    Punjab Kings     Indore
# 37      STR Binny    Punjab Kings     Indore
# 38      STR Binny    Punjab Kings     Indore
# 39      STR Binny    Punjab Kings     Indore
# 40      STR Binny    Punjab Kings     Indore
# 41      STR Binny    Punjab Kings     Indore
# 42      STR Binny    Punjab Kings     Indore
# 43      STR Binny    Punjab Kings     Indore
# 44      STR Binny    Punjab Kings     Indore
# 45      STR Binny    Punjab Kings     Indore
# 46      STR Binny    Punjab Kings     Indore
# 47      STR Binny    Punjab Kings     Indore
# 48      STR Binny    Punjab Kings     Indore
# 49        V Kohli  Mumbai Indians  Bangalore

# %%
#Goal is prediction of a run based on overs - powerplay, middle overs, death overs (convert overs to categorical)
#                                      bowler_type - available
#                                      previous ball was a no ball? can be obtained easily - free hit means boundary attempt
#                                      bowler_economy previos matches how mnay previous years should I take? featutre problem
#                                      bowler_srike rate - same queston as before
#                                      wckets talen by owler same qestion as previous
#                                      venue - indicator of dimensions
#                                      non striker quality

# %%
with open(path + 'bowler_stats.json') as f:
    bowler_stats = json.load(f)

# %%
bowler_stats_dict = dict(ChainMap(*bowler_stats))

# %% [markdown]
# ### Creating a data set with last three years + until that match bowler stats and non striker stats

# %%
#bowler_stats[0]['Sandeep Sharma'] #- List of years in decreasing order
#bowler_stats[0]['Sandeep Sharma'][0] - Year, Balls, Runs, Wickets, Best figures, Average, Economy, SR etc as keys
#Goal is to create a list (column) that checks for bolwer and the year first and gets prev three years data

ABD_main_V2 = ABD_main.copy()
ABD_main_V2.sort_values(by = 'Date', inplace = True)

# %%
#ABD_main_V2.index[0].year
def f(x,y, sub, label):
    #we are accessing row datetime and bowler name
    #scanning through all rows
  
    try:
        #bowler_stats_dict[y] # - has all years of a bowler
        bowler_year_dict = dict(ChainMap(*bowler_stats_dict[x]))
        
    except:
        
        #When there is no stat
        return np.nan
    
    
    #bowler_year_list
    all_years_list = list(bowler_year_dict.keys())
    
    #Pick the key and access the stats
    try:
        
        stat_for_that_year = float(bowler_year_dict[str(y.year- sub)][label])
        
    except:
        
        #when stat was accidently taken from the wrong website
        return np.nan

    return  stat_for_that_year

#https://stackoverflow.com/questions/13331698/how-to-apply-a-function-to-two-columns-of-pandas-dataframe 
#ABD_main_V2['Econ_this_year'] = ABD_main_V2.apply(lambda x : f(x.Bowler, x.Date, 0, 'Economy'), axis = 1)
ABD_main_V2['Economy_Y - 1'] = ABD_main_V2.apply(lambda x : f(x.Bowler, x.Date, 1, 'Economy'), axis = 1)
ABD_main_V2['Economy_Y - 2'] = ABD_main_V2.apply(lambda x : f(x.Bowler, x.Date, 2, 'Economy'), axis = 1)
ABD_main_V2['Economy_Y - 3'] = ABD_main_V2.apply(lambda x : f(x.Bowler, x.Date, 3, 'Economy'), axis = 1)


#Wickets taken
ABD_main_V2['Wickets_Y - 1'] = ABD_main_V2.apply(lambda x : f(x.Bowler, x.Date, 1, 'Wickets'), axis = 1)
ABD_main_V2['Wickets_Y - 2'] = ABD_main_V2.apply(lambda x : f(x.Bowler, x.Date, 2, 'Wickets'), axis = 1)
ABD_main_V2['Wickets_Y - 3'] = ABD_main_V2.apply(lambda x : f(x.Bowler, x.Date, 3, 'Wickets'), axis = 1)

# %%
ABD_main_V2.dropna(inplace= True)

# %%
ABD_main_V2['3Yr_Econ_Avg'] = round((ABD_main_V2['Economy_Y - 1'] + ABD_main_V2['Economy_Y - 2']\
                                       + ABD_main_V2['Economy_Y - 3']) / 3 , 3)

ABD_main_V2['3Yr_Wickets_Total'] = ABD_main_V2['Wickets_Y - 1'] + ABD_main_V2['Wickets_Y - 2'] \
                                        + ABD_main_V2['Wickets_Y - 3']

# %%
ABD_main_V2.drop(columns = ['Economy_Y - 1', 'Economy_Y - 2', 'Economy_Y - 3', \
                           'Wickets_Y - 1', 'Wickets_Y - 2', 'Wickets_Y - 3'], inplace = True )

# %%
ABD_main_V2.head()
# Out:
#            Date  Over         Over category  BattingOrder  WicketsInHand  \
# 1194 2011-04-09  13.4  Middle Overs (10-16)             4              5
# 1190 2011-04-09  12.2  Middle Overs (10-16)             4              5
# 1191 2011-04-09  12.3  Middle Overs (10-16)             4              5
# 1192 2011-04-09  13.2  Middle Overs (10-16)             4              5
# 1193 2011-04-09  13.3  Middle Overs (10-16)             4              5
#
#               Bowler            Bowler Type  Runs  Extras ExtraType   Status  \
# 1194   R Vinay Kumar  Right-arm fast-medium     1       0     legal  Not Out
# 1190  M Muralitharan     Right-arm offbreak     6       0     legal  Not Out
# 1191  M Muralitharan     Right-arm offbreak     1       0     legal  Not Out
# 1192   R Vinay Kumar  Right-arm fast-medium     0       0     legal  Not Out
# 1193   R Vinay Kumar  Right-arm fast-medium     0       0     legal  Not Out
#
#      Non Striker            Opposition  Venue  3Yr_Econ_Avg  3Yr_Wickets_Total
# 1194   SS Tiwary  Kochi Tuskers Kerala  Kochi         8.287               30.0
# 1190   SS Tiwary  Kochi Tuskers Kerala  Kochi         6.343               40.0
# 1191   SS Tiwary  Kochi Tuskers Kerala  Kochi         6.343               40.0
# 1192   SS Tiwary  Kochi Tuskers Kerala  Kochi         8.287               30.0
# 1193   SS Tiwary  Kochi Tuskers Kerala  Kochi         8.287               30.0

# %%
ABD_main_V2.sort_values(by = ['Date', 'Over'], inplace= True)

# %%
##### IGNORE ###############

# %%
#ABD_main_V2['PreviousBallType'] = ABD_main_V2['Extra Type'].shift(1)

# %%
"""
test = ABD_main_V2[['Over', 'Extra Type']]
test['PrevBall'] = test['Over'].shift(1)
test.dropna(inplace = True)
test['DiffBall'] = test['Over'] - test['PrevBall']
def func(e, d):
    if float(d) == 0.1 and e != 'legal':
        return e
    else: return 'legal'
    
test['PrevBallType'] = test.apply(lambda x : func(x['Extra Type'], x['DiffBall']))
"""
# Out:
# "\ntest = ABD_main_V2[['Over', 'Extra Type']]\ntest['PrevBall'] = test['Over'].shift(1)\ntest.dropna(inplace = True)\ntest['DiffBall'] = test['Over'] - test['PrevBall']\ndef func(e, d):\n    if float(d) == 0.1 and e != 'legal':\n        return e\n    else: return 'legal'\n    \ntest['PrevBallType'] = test.apply(lambda x : func(x['Extra Type'], x['DiffBall']))\n"

# %%
###### END IGNORE ##########

# %%
#Rearrange columns
new_cols = ['Date', 'Over', 'Over category', 'BattingOrder', 'WicketsInHand',  'Non Striker', \
            'Bowler', 'Bowler Type', '3Yr_Econ_Avg', '3Yr_Wickets_Total', 'Status' \
                ,'Opposition', 'Venue', 'Runs' ]
ABD_main_V2 = ABD_main_V2[new_cols]

# %%
ABD_main_V2.head(200)
# Out:
#            Date  Over         Over category  BattingOrder  WicketsInHand  \
# 1166 2011-04-09   5.4            Power Play             4              6
# 1167 2011-04-09   5.5            Power Play             4              6
# 1168 2011-04-09   5.6            Power Play             4              6
# 1169 2011-04-09   6.4   Middle Overs (6-10)             4              6
# 1170 2011-04-09   6.5   Middle Overs (6-10)             4              6
# 1171 2011-04-09   6.6   Middle Overs (6-10)             4              6
# 1172 2011-04-09   7.4   Middle Overs (6-10)             4              6
# 1173 2011-04-09   8.1   Middle Overs (6-10)             4              6
# 1174 2011-04-09   8.3   Middle Overs (6-10)             4              6
# 1175 2011-04-09   8.5   Middle Overs (6-10)             4              6
# 1176 2011-04-09   8.7   Middle Overs (6-10)             4              6
# 1177 2011-04-09   8.8   Middle Overs (6-10)             4              6
# 1182 2011-04-09  10.1  Middle Overs (10-16)             4              5
# 1183 2011-04-09  10.2  Middle Overs (10-16)             4              5
# 1184 2011-04-09  10.3  Middle Overs (10-16)             4              5
# 1185 2011-04-09  10.4  Middle Overs (10-16)             4              5
# 1190 2011-04-09  12.2  Middle Overs (10-16)             4              5
# 1191 2011-04-09  12.3  Middle Overs (10-16)             4              5
# 1192 2011-04-09  13.2  Middle Overs (10-16)             4              5
# 1193 2011-04-09  13.3  Middle Overs (10-16)             4              5
# 1194 2011-04-09  13.4  Middle Overs (10-16)             4              5
# 1195 2011-04-09  14.7  Middle Overs (10-16)             4              5
# 1200 2011-04-09  16.1           Death Overs             4              5
# 1201 2011-04-09  16.3           Death Overs             4              5
# 1202 2011-04-09  16.4           Death Overs             4              5
# 1218 2011-04-12   8.5   Middle Overs (6-10)             4              6
# 1219 2011-04-12   8.6   Middle Overs (6-10)             4              6
# 1224 2011-04-12  10.1  Middle Overs (10-16)             4              6
# 1225 2011-04-12  10.3  Middle Overs (10-16)             4              6
# 1226 2011-04-12  10.4  Middle Overs (10-16)             4              6
# ...         ...   ...                   ...           ...            ...
# 1593 2012-05-14   6.4   Middle Overs (6-10)             5              5
# 1594 2012-05-14   7.1   Middle Overs (6-10)             5              5
# 1595 2012-05-14   7.2   Middle Overs (6-10)             5              5
# 1596 2012-05-14   7.3   Middle Overs (6-10)             5              5
# 1597 2012-05-14   7.6   Middle Overs (6-10)             5              5
# 1598 2012-05-14   8.3   Middle Overs (6-10)             5              5
# 1600 2012-05-14  10.1  Middle Overs (10-16)             5              5
# 1601 2012-05-14  10.3  Middle Overs (10-16)             5              5
# 1602 2012-05-14  10.4  Middle Overs (10-16)             5              5
# 1603 2012-05-14  10.7  Middle Overs (10-16)             5              5
# 1610 2012-05-20   7.4   Middle Overs (6-10)             5              5
# 1611 2012-05-20   7.5   Middle Overs (6-10)             5              5
# 1612 2012-05-20   7.6   Middle Overs (6-10)             5              5
# 1616 2012-05-20   9.2   Middle Overs (6-10)             5              5
# 1764 2013-04-09   7.1   Middle Overs (6-10)             4              6
# 1765 2013-04-09   7.2   Middle Overs (6-10)             4              6
# 1766 2013-04-09   7.3   Middle Overs (6-10)             4              6
# 1767 2013-04-09   7.4   Middle Overs (6-10)             4              6
# 1768 2013-04-09   8.2   Middle Overs (6-10)             4              6
# 1769 2013-04-09   8.6   Middle Overs (6-10)             4              6
# 1770 2013-04-09   9.4   Middle Overs (6-10)             4              6
# 1771 2013-04-09   9.6   Middle Overs (6-10)             4              6
# 1617 2013-04-11   9.2   Middle Overs (6-10)             4              6
# 1618 2013-04-11   9.3   Middle Overs (6-10)             4              6
# 1619 2013-04-11   9.4   Middle Overs (6-10)             4              6
# 1620 2013-04-11   9.5   Middle Overs (6-10)             4              6
# 1625 2013-04-11  11.3  Middle Overs (10-16)             4              6
# 1629 2013-04-11  13.2  Middle Overs (10-16)             4              6
# 1635 2013-04-11  16.2           Death Overs             4              6
# 1636 2013-04-11  16.3           Death Overs             4              6
#
#      Non Striker           Bowler            Bowler Type  3Yr_Econ_Avg  \
# 1166  MA Agarwal    R Vinay Kumar  Right-arm fast-medium         8.287
# 1167  MA Agarwal    R Vinay Kumar  Right-arm fast-medium         8.287
# 1168  MA Agarwal    R Vinay Kumar  Right-arm fast-medium         8.287
# 1169  MA Agarwal   M Muralitharan     Right-arm offbreak         6.343
# 1170  MA Agarwal   M Muralitharan     Right-arm offbreak         6.343
# 1171  MA Agarwal   M Muralitharan     Right-arm offbreak         6.343
# 1172  MA Agarwal    R Vinay Kumar  Right-arm fast-medium         8.287
# 1173  MA Agarwal      S Sreesanth  Right-arm fast-medium         9.007
# 1174  MA Agarwal      S Sreesanth  Right-arm fast-medium         9.007
# 1175  MA Agarwal      S Sreesanth  Right-arm fast-medium         9.007
# 1176  MA Agarwal      S Sreesanth  Right-arm fast-medium         9.007
# 1177  MA Agarwal      S Sreesanth  Right-arm fast-medium         9.007
# 1182   SS Tiwary   M Muralitharan     Right-arm offbreak         6.343
# 1183   SS Tiwary   M Muralitharan     Right-arm offbreak         6.343
# 1184   SS Tiwary   M Muralitharan     Right-arm offbreak         6.343
# 1185   SS Tiwary   M Muralitharan     Right-arm offbreak         6.343
# 1190   SS Tiwary   M Muralitharan     Right-arm offbreak         6.343
# 1191   SS Tiwary   M Muralitharan     Right-arm offbreak         6.343
# 1192   SS Tiwary    R Vinay Kumar  Right-arm fast-medium         8.287
# 1193   SS Tiwary    R Vinay Kumar  Right-arm fast-medium         8.287
# 1194   SS Tiwary    R Vinay Kumar  Right-arm fast-medium         8.287
# 1195   SS Tiwary         RP Singh   Left-arm fast-medium         8.130
# 1200   SS Tiwary   M Muralitharan     Right-arm offbreak         6.343
# 1201   SS Tiwary   M Muralitharan     Right-arm offbreak         6.343
# 1202   SS Tiwary   M Muralitharan     Right-arm offbreak         6.343
# 1218  TM Dilshan  Harbhajan Singh     Right-arm offbreak         7.017
# 1219  TM Dilshan  Harbhajan Singh     Right-arm offbreak         7.017
# 1224  TM Dilshan  Harbhajan Singh     Right-arm offbreak         7.017
# 1225  TM Dilshan  Harbhajan Singh     Right-arm offbreak         7.017
# 1226  TM Dilshan  Harbhajan Singh     Right-arm offbreak         7.017
# ...          ...              ...                    ...           ...
# 1593  TM Dilshan  Harbhajan Singh     Right-arm offbreak         6.610
# 1594  TM Dilshan       SL Malinga         Right-arm fast         6.423
# 1595  TM Dilshan       SL Malinga         Right-arm fast         6.423
# 1596  TM Dilshan       SL Malinga         Right-arm fast         6.423
# 1597  TM Dilshan       SL Malinga         Right-arm fast         6.423
# 1598  TM Dilshan  Harbhajan Singh     Right-arm offbreak         6.610
# 1600  TM Dilshan  Harbhajan Singh     Right-arm offbreak         6.610
# 1601  TM Dilshan  Harbhajan Singh     Right-arm offbreak         6.610
# 1602  TM Dilshan  Harbhajan Singh     Right-arm offbreak         6.610
# 1603  TM Dilshan  Harbhajan Singh     Right-arm offbreak         6.610
# 1610     V Kohli         A Mishra     Right-arm legbreak         6.840
# 1611     V Kohli         A Mishra     Right-arm legbreak         6.840
# 1612     V Kohli         A Mishra     Right-arm legbreak         6.840
# 1616     V Kohli         A Mishra     Right-arm legbreak         6.840
# 1764     V Kohli         A Mishra     Right-arm legbreak         7.190
# 1765     V Kohli         A Mishra     Right-arm legbreak         7.190
# 1766     V Kohli         A Mishra     Right-arm legbreak         7.190
# 1767     V Kohli         A Mishra     Right-arm legbreak         7.190
# 1768     V Kohli      NLTC Perera  Right-arm fast-medium        12.573
# 1769     V Kohli      NLTC Perera  Right-arm fast-medium        12.573
# 1770     V Kohli         A Mishra     Right-arm legbreak         7.190
# 1771     V Kohli         A Mishra     Right-arm legbreak         7.190
# 1617    CH Gayle         L Balaji  Right-arm fast-medium         7.553
# 1618    CH Gayle         L Balaji  Right-arm fast-medium         7.553
# 1619    CH Gayle         L Balaji  Right-arm fast-medium         7.553
# 1620    CH Gayle         L Balaji  Right-arm fast-medium         7.553
# 1625    CH Gayle         L Balaji  Right-arm fast-medium         7.553
# 1629    CH Gayle        JH Kallis  Right-arm fast-medium         7.630
# 1635    CH Gayle         R Bhatia       Right-arm medium         7.373
# 1636    CH Gayle         R Bhatia       Right-arm medium         7.373
#
#       3Yr_Wickets_Total   Status             Opposition      Venue  Runs
# 1166               30.0  Not Out   Kochi Tuskers Kerala      Kochi     0
# 1167               30.0  Not Out   Kochi Tuskers Kerala      Kochi     0
# 1168               30.0  Not Out   Kochi Tuskers Kerala      Kochi     0
# 1169               40.0  Not Out   Kochi Tuskers Kerala      Kochi     2
# 1170               40.0  Not Out   Kochi Tuskers Kerala      Kochi     0
# 1171               40.0  Not Out   Kochi Tuskers Kerala      Kochi     0
# 1172               30.0  Not Out   Kochi Tuskers Kerala      Kochi     1
# 1173               28.0  Not Out   Kochi Tuskers Kerala      Kochi     1
# 1174               28.0  Not Out   Kochi Tuskers Kerala      Kochi     1
# 1175               28.0  Not Out   Kochi Tuskers Kerala      Kochi     1
# 1176               28.0  Not Out   Kochi Tuskers Kerala      Kochi     6
# 1177               28.0  Not Out   Kochi Tuskers Kerala      Kochi     1
# 1182               40.0  Not Out   Kochi Tuskers Kerala      Kochi     0
# 1183               40.0  Not Out   Kochi Tuskers Kerala      Kochi     0
# 1184               40.0  Not Out   Kochi Tuskers Kerala      Kochi     0
# 1185               40.0  Not Out   Kochi Tuskers Kerala      Kochi     1
# 1190               40.0  Not Out   Kochi Tuskers Kerala      Kochi     6
# 1191               40.0  Not Out   Kochi Tuskers Kerala      Kochi     1
# 1192               30.0  Not Out   Kochi Tuskers Kerala      Kochi     0
# 1193               30.0  Not Out   Kochi Tuskers Kerala      Kochi     0
# 1194               30.0  Not Out   Kochi Tuskers Kerala      Kochi     1
# 1195               51.0  Not Out   Kochi Tuskers Kerala      Kochi     1
# 1200               40.0  Not Out   Kochi Tuskers Kerala      Kochi     1
# 1201               40.0  Not Out   Kochi Tuskers Kerala      Kochi     0
# 1202               40.0  Not Out   Kochi Tuskers Kerala      Kochi     1
# 1218               34.0  Not Out         Mumbai Indians  Bangalore     0
# 1219               34.0  Not Out         Mumbai Indians  Bangalore     1
# 1224               34.0  Not Out         Mumbai Indians  Bangalore     1
# 1225               34.0  Not Out         Mumbai Indians  Bangalore     0
# 1226               34.0  Not Out         Mumbai Indians  Bangalore     0
# ...                 ...      ...                    ...        ...   ...
# 1593               43.0  Not Out         Mumbai Indians  Bangalore     1
# 1594               61.0  Not Out         Mumbai Indians  Bangalore     0
# 1595               61.0  Not Out         Mumbai Indians  Bangalore     0
# 1596               61.0  Not Out         Mumbai Indians  Bangalore     1
# 1597               61.0  Not Out         Mumbai Indians  Bangalore     2
# 1598               43.0  Not Out         Mumbai Indians  Bangalore     1
# 1600               43.0  Not Out         Mumbai Indians  Bangalore     1
# 1601               43.0  Not Out         Mumbai Indians  Bangalore     4
# 1602               43.0  Not Out         Mumbai Indians  Bangalore     1
# 1603               43.0  Not Out         Mumbai Indians  Bangalore     1
# 1610               50.0  Not Out    Sunrisers Hyderabad  Hyderabad     0
# 1611               50.0  Not Out    Sunrisers Hyderabad  Hyderabad     0
# 1612               50.0  Not Out    Sunrisers Hyderabad  Hyderabad     1
# 1616               50.0   caught    Sunrisers Hyderabad  Hyderabad     0
# 1764               49.0  Not Out    Sunrisers Hyderabad  Bangalore     0
# 1765               49.0  Not Out    Sunrisers Hyderabad  Bangalore     0
# 1766               49.0  Not Out    Sunrisers Hyderabad  Bangalore     0
# 1767               49.0  Not Out    Sunrisers Hyderabad  Bangalore     1
# 1768                2.0  Not Out    Sunrisers Hyderabad  Bangalore     1
# 1769                2.0  Not Out    Sunrisers Hyderabad  Bangalore     2
# 1770               49.0  Not Out    Sunrisers Hyderabad  Bangalore     1
# 1771               49.0  Not Out    Sunrisers Hyderabad  Bangalore     1
# 1617               28.0  Not Out  Kolkata Knight Riders  Bangalore     0
# 1618               28.0  Not Out  Kolkata Knight Riders  Bangalore     0
# 1619               28.0  Not Out  Kolkata Knight Riders  Bangalore     0
# 1620               28.0  Not Out  Kolkata Knight Riders  Bangalore     1
# 1625               28.0  Not Out  Kolkata Knight Riders  Bangalore     1
# 1629               35.0  Not Out  Kolkata Knight Riders  Bangalore     1
# 1635               24.0  Not Out  Kolkata Knight Riders  Bangalore     0
# 1636               24.0  Not Out  Kolkata Knight Riders  Bangalore     6
#
# [200 rows x 14 columns]

# %%
#all_data['Order Day new'] = all_data['Order Day new'].dt.strftime('%Y-%m-%d')
ABD_main_V2['Date'] = ABD_main_V2['Date'].dt.strftime('%Y-%m-%d')

# %%
#Cumulatve runs scored by AB to any bowler
#Could be useful for exploratoty
#Without a bowler name could cum runs for a bowler (rep as type) represt AB laying safe or taking the bowler on
matchdate_bowler_group =  ABD_main_V2.groupby(['Date', 'Bowler', 'Over']).sum().groupby('Bowler').cumsum()
matchdate_bowler_group.drop(columns = ['3Yr_Econ_Avg', '3Yr_Wickets_Total'], inplace = True)
def func(d, b, o): 
    return matchdate_bowler_group.loc[d, b, o][0]
    
ABD_main_V2['CumulativeRunsForBowler'] = ABD_main_V2.apply(lambda x : func(x.Date, x.Bowler, x.Over), axis = 1)

# %%
#Quantifying the situation of the match
#Starting with batting position and wickets in hand
# We have batting position
ABD_main_V2['BattingOrder'].unique()
# Out:
# array([4, 5, 6, 3], dtype=int64)

# %%
ABD_main_V2.to_csv('Runs_ThreeYearAvgWickets.csv')
